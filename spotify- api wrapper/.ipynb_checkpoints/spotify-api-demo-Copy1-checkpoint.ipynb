# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("secrets.txt","r") # exact file name or the path of the file where it comes from.
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        print(line.split(':'))# gives a list 
        secrets_dict[line.split(':')[0]]=line.split(':')[1]
# Out:
# ['cid', '3ff19e99b13f4376a0e01e3a56ee6d40']
# ['csecret', '9c17a9a9f8f84b0bb8967f84bc4dab7c']

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %%
# Reusable functions
def get_name_artists_from_track(track):
    return [(track["name"],artist["name"], track["uri"]) for artist in track["artists"]]

def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

#first we need to get a list of individual tracks from the playlist
def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

def get_name_artists_from_playlist_items(playlist_items):
    return flatten(list(map(get_name_artist_from_playlist_item,playlist_items)))

# %%
# Get all the tracks from a playlist by applying pagination
from random import randint
from time import sleep

def get_playlist_items(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    items = results['items']
    while results['next']!=None:
        print('Fetching {0} page out of {1}'.format(results['offset'], results['total']))
        results = sp.next(results)
        items = items + results['items']
        sleep(randint(1,3))
    print('Done!')
    return items

# %%
# this will take at least around num_songs_in_playlist * (avg_sleep_time + processing_time) = (number of songs/100) * (2+0.1) = 110 seconds

playlists = ['2HTcOvM2Yq1qNRsGIsW0nW']
all_items = []
for playlist in playlists:
    all_items.extend(get_playlist_items(playlist))
len(all_items)
# Out:
# Fetching 0 page out of 8080
# Fetching 100 page out of 8080
# Fetching 200 page out of 8080
# Fetching 300 page out of 8080
# Fetching 400 page out of 8080
# Fetching 500 page out of 8080
# Fetching 600 page out of 8080
# Fetching 700 page out of 8080
# Fetching 800 page out of 8080
# Fetching 900 page out of 8080
# Fetching 1000 page out of 8080
# Fetching 1100 page out of 8080
# Fetching 1200 page out of 8080
# Fetching 1300 page out of 8080
# Fetching 1400 page out of 8080
# Fetching 1500 page out of 8080
# Fetching 1600 page out of 8080
# Fetching 1700 page out of 8080
# Fetching 1800 page out of 8080
# Fetching 1900 page out of 8080
# Fetching 2000 page out of 8080
# Fetching 2100 page out of 8080
# Fetching 2200 page out of 8080
# Fetching 2300 page out of 8080
# Fetching 2400 page out of 8080
# Fetching 2500 page out of 8080
# Fetching 2600 page out of 8080
# Fetching 2700 page out of 8080
# Fetching 2800 page out of 8080
# Fetching 2900 page out of 8080
# Fetching 3000 page out of 8080
# Fetching 3100 page out of 8080
# Fetching 3200 page out of 8080
# Fetching 3300 page out of 8080
# Fetching 3400 page out of 8080
# Fetching 3500 page out of 8080
# Fetching 3600 page out of 8080
# Fetching 3700 page out of 8080
# Fetching 3800 page out of 8080
# Fetching 3900 page out of 8080
# Fetching 4000 page out of 8080
# Fetching 4100 page out of 8080
# Fetching 4200 page out of 8080
# Fetching 4300 page out of 8080
# Fetching 4400 page out of 8080
# Fetching 4500 page out of 8080
# Fetching 4600 page out of 8080
# Fetching 4700 page out of 8080
# Fetching 4800 page out of 8080
# Fetching 4900 page out of 8080
# Fetching 5000 page out of 8080
# Fetching 5100 page out of 8080
# Fetching 5200 page out of 8080
# Fetching 5300 page out of 8080
# Fetching 5400 page out of 8080
# Fetching 5500 page out of 8080
# Fetching 5600 page out of 8080
# Fetching 5700 page out of 8080
# Fetching 5800 page out of 8080
# Fetching 5900 page out of 8080
# Fetching 6000 page out of 8080
# Fetching 6100 page out of 8080
# Fetching 6200 page out of 8080
# Fetching 6300 page out of 8080
# Fetching 6400 page out of 8080
# Fetching 6500 page out of 8080
# Fetching 6600 page out of 8080
# Fetching 6700 page out of 8080
# Fetching 6800 page out of 8080
# Fetching 6900 page out of 8080
# Fetching 7000 page out of 8080
# Fetching 7100 page out of 8080
# Fetching 7200 page out of 8080
# Fetching 7300 page out of 8080
# Fetching 7400 page out of 8080
# Fetching 7500 page out of 8080
# Fetching 7600 page out of 8080
# Fetching 7700 page out of 8080
# Fetching 7800 page out of 8080
# Fetching 7900 page out of 8080
# Done!
# 8080

# %%
track_data = get_name_artists_from_playlist_items(all_items)
track_data[0:10]
# Out:
# [("Hey Leroy, Your Mama's Calling You",
#   'Jimmy Castor',
#   'spotify:track:6DPdkuilLYzkZIGr53HsrG'),
#  ('Bang, Bang', 'Jimmy Castor', 'spotify:track:6puSkh7Unbn3avNFvZMZz1'),
#  ('All I Ever Wanted',
#   'The Human League',
#   'spotify:track:33g1XVNgo3lbDLeRiRQ0TL'),
#  ('Big Time Sensuality - The Fluke Minimix',
#   'Björk',
#   'spotify:track:4Q8b1l8daZE9ALzkd6kKzL'),
#  ('Big Time Sensuality - The Fluke Minimix',
#   'Fluke',
#   'spotify:track:4Q8b1l8daZE9ALzkd6kKzL'),
#  ('Fata Morgana - Original Mix',
#   'Der Dritte Raum',
#   'spotify:track:1yzgJNsnTGZacmsrcvZL4V'),
#  ('Bad Reputation',
#   'Joan Jett & the Blackhearts',
#   'spotify:track:5M5ySjWYS4s6hi2pEvEwb5'),
#  ('My Window', 'The Residents', 'spotify:track:61t7MU96q1DWE8eXBsUGua'),
#  ('Winchester Cathedral',
#   'Jimmy Castor',
#   'spotify:track:5fPsQzd4GMMPt7qePOxnAX'),
#  ('Donna', 'Rubblebucket', 'spotify:track:5UuVuVCEag2VYp8PdWB2eB')]

# %%
import pandas as pd

# Converted track name, artist name and uri from the above to dataframe for merging it with audo features

track_df = pd.DataFrame(track_data, columns = ['track_name', 'artist_name', 'uri'])
print(track_df.shape)
track_df.head(10)
# Out:
# (8686, 3)
#                                 track_name                  artist_name  \
# 0       Hey Leroy, Your Mama's Calling You                 Jimmy Castor
# 1                               Bang, Bang                 Jimmy Castor
# 2                        All I Ever Wanted             The Human League
# 3  Big Time Sensuality - The Fluke Minimix                        Björk
# 4  Big Time Sensuality - The Fluke Minimix                        Fluke
# 5              Fata Morgana - Original Mix              Der Dritte Raum
# 6                           Bad Reputation  Joan Jett & the Blackhearts
# 7                                My Window                The Residents
# 8                     Winchester Cathedral                 Jimmy Castor
# 9                                    Donna                 Rubblebucket
#
#                                     uri
# 0  spotify:track:6DPdkuilLYzkZIGr53HsrG
# 1  spotify:track:6puSkh7Unbn3avNFvZMZz1
# 2  spotify:track:33g1XVNgo3lbDLeRiRQ0TL
# 3  spotify:track:4Q8b1l8daZE9ALzkd6kKzL
# 4  spotify:track:4Q8b1l8daZE9ALzkd6kKzL
# 5  spotify:track:1yzgJNsnTGZacmsrcvZL4V
# 6  spotify:track:5M5ySjWYS4s6hi2pEvEwb5
# 7  spotify:track:61t7MU96q1DWE8eXBsUGua
# 8  spotify:track:5fPsQzd4GMMPt7qePOxnAX
# 9  spotify:track:5UuVuVCEag2VYp8PdWB2eB

# %%
all_items[0]['track']['uri']
# Out:
# 'spotify:track:6DPdkuilLYzkZIGr53HsrG'

# %%
import numpy as np

def get_track_uri(item):
    return item['track']['uri']

def get_track_uris(items):
    return list(map(get_track_uri, items))

track_uris = get_track_uris(all_items)
print(len(track_uris))

# Filter out non track uris (spotify:local:songname) as they cause error during fetching audio features
track_uris = list(filter(lambda x: 'spotify:track:' in x, track_uris))
print(len(track_uris))

# took from the stackoverflow "https://stackoverflow.com/questions/312443/how-do-i-split-a-list-into-equally-sized-chunks"

def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# Split track_uris list in to chunks of 100 (sub list), so that I can use bulk audio_features request, instead of one by one
track_uris_batch = list(chunks(track_uris, 100))
track_uris_batch[0:2]
# Out:
# 8080
# 8076
# [['spotify:track:6DPdkuilLYzkZIGr53HsrG',
#   'spotify:track:6puSkh7Unbn3avNFvZMZz1',
#   'spotify:track:33g1XVNgo3lbDLeRiRQ0TL',
#   'spotify:track:4Q8b1l8daZE9ALzkd6kKzL',
#   'spotify:track:1yzgJNsnTGZacmsrcvZL4V',
#   'spotify:track:5M5ySjWYS4s6hi2pEvEwb5',
#   'spotify:track:61t7MU96q1DWE8eXBsUGua',
#   'spotify:track:5fPsQzd4GMMPt7qePOxnAX',
#   'spotify:track:5UuVuVCEag2VYp8PdWB2eB',
#   'spotify:track:43ievcG8mUfVBVn5OJkTrC',
#   'spotify:track:1SgN3j9jMbcZuiyrSnISz9',
#   'spotify:track:50NbWayQdJBN6bOMAX6ToV',
#   'spotify:track:0EYKD5N0mldDeVTCzCfzqr',
#   'spotify:track:6ZtUudtvm3fmY1lH7DUyOI',
#   'spotify:track:0Z8A6Kg5RNijfaRoGF2p64',
#   'spotify:track:4UncGeJfZIIhAuXbINRf5E',
#   'spotify:track:6SFCvojUWUqdWldrwVbOOT',
#   'spotify:track:0BzPIlaQ5NGAWXmYcGxjwW',
#   'spotify:track:5M6hQO5GP9LiOX1mDnCkfB',
#   'spotify:track:3LcupwswRKl1ksF8moWX9H',
#   'spotify:track:6rDeD5wQ1vcAMG2SpQOPed',
#   'spotify:track:25zeHP11go4rGsTdMmrQI7',
#   'spotify:track:5GfBJkcVh9BYrmTssKuO2n',
#   'spotify:track:1ZWbfmoCmTmEFf02hCw2tS',
#   'spotify:track:2ENmfywUgnGAyhAK9yLvLz',
#   'spotify:track:0aiMklluzV7MN7nCrz6Up1',
#   'spotify:track:3AP16mgHpBvJQ8wA389X66',
#   'spotify:track:6Oz9XfeBlYgbwX8BN4uvQn',
#   'spotify:track:2suUegnmP8jpABRXITTtHN',
#   'spotify:track:2bdWtqHiadkjbzjh8bZSk0',
#   'spotify:track:2H7PHVdQ3mXqEHXcvclTB0',
#   'spotify:track:3uzSH4U0gyITuqimTp8HuL',
#   'spotify:track:5ZYcXdiQMOqqqjlvfgwpbC',
#   'spotify:track:0HHdfCcmF6EElG0SgDNCGw',
#   'spotify:track:7fX8LYZdOkv9vbY9XBfggZ',
#   'spotify:track:77waPYzs7Cr2HTa394wVGM',
#   'spotify:track:5ikdAD7wufpXNb8aSFFDPT',
#   'spotify:track:2ePS8oLQEpNCM5imRUO58L',
#   'spotify:track:49ERAIOFzOPe5CG4ejp2UL',
#   'spotify:track:3g48cSfrQsyjWg3uVxATaY',
#   'spotify:track:5mpK3PwhJPwZG6EqutrHMW',
#   'spotify:track:25ONd5KLodHeHOvALtWG1T',
#   'spotify:track:0JTexNTWFuNLw4U5TDnUYj',
#   'spotify:track:4H2o0a7BT5aN647N3Ypy4t',
#   'spotify:track:4ITNvKm0xxAu1ILtrO0Gp0',
#   'spotify:track:787NC0R3QWEQeEuaPk9kjr',
#   'spotify:track:7i01XL38BLcXWGsI2MLe7p',
#   'spotify:track:4eytIj1CDefMixAjuYy3M8',
#   'spotify:track:5cDIClJAMV6ETYEuKztjxN',
#   'spotify:track:3dNtrN57LGNBQimQeOTd3v',
#   'spotify:track:26jQscwbAyk1cJYfOWS2BN',
#   'spotify:track:2E1g5Oh0F32n85KNekk7Ze',
#   'spotify:track:11AD6dHa8NcifLw8WdErZS',
#   'spotify:track:2XIs3A5GWPBkKuHHa93GWa']]

# %%
# For all the tracks, get the audio features one by one and append it to a list
audio_features = []
for i, track_uri in enumerate(track_uris_batch):
    print('Fetching audio feature for track number {0} from {1}'.format(i, len(track_uris_batch)))
    audio_feature = sp.audio_features(track_uri)
    audio_features.extend(audio_feature)
    sleep(randint(1,3))
print('Done')
audio_features[0:50]
# Out:
# Fetching audio feature for track number 0 from 81
# Fetching audio feature for track number 1 from 81
# Fetching audio feature for track number 2 from 81
# Fetching audio feature for track number 3 from 81
# Fetching audio feature for track number 4 from 81
# Fetching audio feature for track number 5 from 81
# Fetching audio feature for track number 6 from 81
# Fetching audio feature for track number 7 from 81
# Fetching audio feature for track number 8 from 81
# Fetching audio feature for track number 9 from 81
# Fetching audio feature for track number 10 from 81
# Fetching audio feature for track number 11 from 81
# Fetching audio feature for track number 12 from 81
# Fetching audio feature for track number 13 from 81
# Fetching audio feature for track number 14 from 81
# Fetching audio feature for track number 15 from 81
# Fetching audio feature for track number 16 from 81
# Fetching audio feature for track number 17 from 81
# Fetching audio feature for track number 18 from 81
# Fetching audio feature for track number 19 from 81
# Fetching audio feature for track number 20 from 81
# Fetching audio feature for track number 21 from 81
# Fetching audio feature for track number 22 from 81
# Fetching audio feature for track number 23 from 81
# Fetching audio feature for track number 24 from 81
# Fetching audio feature for track number 25 from 81
# Fetching audio feature for track number 26 from 81
# Fetching audio feature for track number 27 from 81
# Fetching audio feature for track number 28 from 81
# Fetching audio feature for track number 29 from 81
# Fetching audio feature for track number 30 from 81
# Fetching audio feature for track number 31 from 81
# Fetching audio feature for track number 32 from 81
# Fetching audio feature for track number 33 from 81
# Fetching audio feature for track number 34 from 81
# Fetching audio feature for track number 35 from 81
# Fetching audio feature for track number 36 from 81
# Fetching audio feature for track number 37 from 81
# Fetching audio feature for track number 38 from 81
# Fetching audio feature for track number 39 from 81
# Fetching audio feature for track number 40 from 81
# Fetching audio feature for track number 41 from 81
# Fetching audio feature for track number 42 from 81
# Fetching audio feature for track number 43 from 81
# Fetching audio feature for track number 44 from 81
# Fetching audio feature for track number 45 from 81
# Fetching audio feature for track number 46 from 81
# Fetching audio feature for track number 47 from 81
# Fetching audio feature for track number 48 from 81
# Fetching audio feature for track number 49 from 81
# Fetching audio feature for track number 50 from 81
# Fetching audio feature for track number 51 from 81
# Fetching audio feature for track number 52 from 81
# Fetching audio feature for track number 53 from 81
# Fetching audio feature for track number 54 from 81
# Fetching audio feature for track number 55 from 81
# Fetching audio feature for track number 56 from 81
# Fetching audio feature for track number 57 from 81
# Fetching audio feature for track number 58 from 81
# Fetching audio feature for track number 59 from 81
# Fetching audio feature for track number 60 from 81
# Fetching audio feature for track number 61 from 81
# Fetching audio feature for track number 62 from 81
# Fetching audio feature for track number 63 from 81
# Fetching audio feature for track number 64 from 81
# Fetching audio feature for track number 65 from 81
# Fetching audio feature for track number 66 from 81
# Fetching audio feature for track number 67 from 81
# Fetching audio feature for track number 68 from 81
# Fetching audio feature for track number 69 from 81
# Fetching audio feature for track number 70 from 81
# Fetching audio feature for track number 71 from 81
# Fetching audio feature for track number 72 from 81
# Fetching audio feature for track number 73 from 81
# Fetching audio feature for track number 74 from 81
# Fetching audio feature for track number 75 from 81
# Fetching audio feature for track number 76 from 81
# Fetching audio feature for track number 77 from 81
# Fetching audio feature for track number 78 from 81
# Fetching audio feature for track number 79 from 81
# Fetching audio feature for track number 80 from 81
# Done
# [{'danceability': 0.714,
#   'energy': 0.765,
#   'key': 0,
#   'loudness': -9.38,
#   'mode': 1,
#   'speechiness': 0.0406,
#   'acousticness': 0.41,
#   'instrumentalness': 0.508,
#   'liveness': 0.119,
#   'valence': 0.961,
#   'tempo': 105.796,
#   'type': 'audio_features',
#   'id': '6DPdkuilLYzkZIGr53HsrG',
#   'uri': 'spotify:track:6DPdkuilLYzkZIGr53HsrG',
#   'track_href': 'https://api.spotify.com/v1/tracks/6DPdkuilLYzkZIGr53HsrG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6DPdkuilLYzkZIGr53HsrG',
#   'duration_ms': 148440,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.878,
#   'key': 3,
#   'loudness': -9.544,
#   'mode': 1,
#   'speechiness': 0.0312,
#   'acousticness': 0.833,
#   'instrumentalness': 0.000402,
#   'liveness': 0.0888,
#   'valence': 0.936,
#   'tempo': 129.957,
#   'type': 'audio_features',
#   'id': '6puSkh7Unbn3avNFvZMZz1',
#   'uri': 'spotify:track:6puSkh7Unbn3avNFvZMZz1',
#   'track_href': 'https://api.spotify.com/v1/tracks/6puSkh7Unbn3avNFvZMZz1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6puSkh7Unbn3avNFvZMZz1',
#   'duration_ms': 188160,
#   'time_signature': 4},
#  {'danceability': 0.649,
#   'energy': 0.789,
#   'key': 0,
#   'loudness': -9.466,
#   'mode': 1,
#   'speechiness': 0.0264,
#   'acousticness': 0.00441,
#   'instrumentalness': 1.55e-06,
#   'liveness': 0.0859,
#   'valence': 0.931,
#   'tempo': 129.549,
#   'type': 'audio_features',
#   'id': '33g1XVNgo3lbDLeRiRQ0TL',
#   'uri': 'spotify:track:33g1XVNgo3lbDLeRiRQ0TL',
#   'track_href': 'https://api.spotify.com/v1/tracks/33g1XVNgo3lbDLeRiRQ0TL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33g1XVNgo3lbDLeRiRQ0TL',
#   'duration_ms': 234333,
#   'time_signature': 4},
#  {'danceability': 0.644,
#   'energy': 0.785,
#   'key': 8,
#   'loudness': -8.642,
#   'mode': 1,
#   'speechiness': 0.0284,
#   'acousticness': 0.00032,
#   'instrumentalness': 0.116,
#   'liveness': 0.0451,
#   'valence': 0.668,
#   'tempo': 116.938,
#   'type': 'audio_features',
#   'id': '4Q8b1l8daZE9ALzkd6kKzL',
#   'uri': 'spotify:track:4Q8b1l8daZE9ALzkd6kKzL',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Q8b1l8daZE9ALzkd6kKzL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Q8b1l8daZE9ALzkd6kKzL',
#   'duration_ms': 293840,
#   'time_signature': 4},
#  {'danceability': 0.81,
#   'energy': 0.658,
#   'key': 2,
#   'loudness': -9.676,
#   'mode': 1,
#   'speechiness': 0.0463,
#   'acousticness': 0.00348,
#   'instrumentalness': 0.922,
#   'liveness': 0.0744,
#   'valence': 0.743,
#   'tempo': 126.009,
#   'type': 'audio_features',
#   'id': '1yzgJNsnTGZacmsrcvZL4V',
#   'uri': 'spotify:track:1yzgJNsnTGZacmsrcvZL4V',
#   'track_href': 'https://api.spotify.com/v1/tracks/1yzgJNsnTGZacmsrcvZL4V',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1yzgJNsnTGZacmsrcvZL4V',
#   'duration_ms': 339524,
#   'time_signature': 4},
#  {'danceability': 0.385,
#   'energy': 0.975,
#   'key': 6,
#   'loudness': -4.099,
#   'mode': 1,
#   'speechiness': 0.192,
#   'acousticness': 0.00197,
#   'instrumentalness': 0.0167,
#   'liveness': 0.0602,
#   'valence': 0.821,
#   'tempo': 204.397,
#   'type': 'audio_features',
#   'id': '5M5ySjWYS4s6hi2pEvEwb5',
#   'uri': 'spotify:track:5M5ySjWYS4s6hi2pEvEwb5',
#   'track_href': 'https://api.spotify.com/v1/tracks/5M5ySjWYS4s6hi2pEvEwb5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5M5ySjWYS4s6hi2pEvEwb5',
#   'duration_ms': 170841,
#   'time_signature': 4},
#  {'danceability': 0.205,
#   'energy': 0.246,
#   'key': 8,
#   'loudness': -16.175,
#   'mode': 1,
#   'speechiness': 0.0313,
#   'acousticness': 0.245,
#   'instrumentalness': 0.602,
#   'liveness': 0.111,
#   'valence': 0.0343,
#   'tempo': 97.059,
#   'type': 'audio_features',
#   'id': '61t7MU96q1DWE8eXBsUGua',
#   'uri': 'spotify:track:61t7MU96q1DWE8eXBsUGua',
#   'track_href': 'https://api.spotify.com/v1/tracks/61t7MU96q1DWE8eXBsUGua',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61t7MU96q1DWE8eXBsUGua',
#   'duration_ms': 320960,
#   'time_signature': 3},
#  {'danceability': 0.756,
#   'energy': 0.803,
#   'key': 2,
#   'loudness': -9.508,
#   'mode': 0,
#   'speechiness': 0.0956,
#   'acousticness': 0.427,
#   'instrumentalness': 0.0724,
#   'liveness': 0.0824,
#   'valence': 0.878,
#   'tempo': 136.568,
#   'type': 'audio_features',
#   'id': '5fPsQzd4GMMPt7qePOxnAX',
#   'uri': 'spotify:track:5fPsQzd4GMMPt7qePOxnAX',
#   'track_href': 'https://api.spotify.com/v1/tracks/5fPsQzd4GMMPt7qePOxnAX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5fPsQzd4GMMPt7qePOxnAX',
#   'duration_ms': 163800,
#   'time_signature': 4},
#  {'danceability': 0.572,
#   'energy': 0.942,
#   'key': 11,
#   'loudness': -3.66,
#   'mode': 0,
#   'speechiness': 0.0448,
#   'acousticness': 0.0028,
#   'instrumentalness': 0.0559,
#   'liveness': 0.35,
#   'valence': 0.814,
#   'tempo': 112.014,
#   'type': 'audio_features',
#   'id': '5UuVuVCEag2VYp8PdWB2eB',
#   'uri': 'spotify:track:5UuVuVCEag2VYp8PdWB2eB',
#   'track_href': 'https://api.spotify.com/v1/tracks/5UuVuVCEag2VYp8PdWB2eB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5UuVuVCEag2VYp8PdWB2eB',
#   'duration_ms': 213813,
#   'time_signature': 4},
#  {'danceability': 0.712,
#   'energy': 0.68,
#   'key': 1,
#   'loudness': -8.132,
#   'mode': 1,
#   'speechiness': 0.0966,
#   'acousticness': 0.135,
#   'instrumentalness': 0,
#   'liveness': 0.629,
#   'valence': 0.527,
#   'tempo': 99.074,
#   'type': 'audio_features',
#   'id': '43ievcG8mUfVBVn5OJkTrC',
#   'uri': 'spotify:track:43ievcG8mUfVBVn5OJkTrC',
#   'track_href': 'https://api.spotify.com/v1/tracks/43ievcG8mUfVBVn5OJkTrC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43ievcG8mUfVBVn5OJkTrC',
#   'duration_ms': 243373,
#   'time_signature': 4},
#  {'danceability': 0.634,
#   'energy': 0.708,
#   'key': 1,
#   'loudness': -3.668,
#   'mode': 1,
#   'speechiness': 0.0271,
#   'acousticness': 0.000364,
#   'instrumentalness': 0.000803,
#   'liveness': 0.129,
#   'valence': 0.253,
#   'tempo': 125.981,
#   'type': 'audio_features',
#   'id': '1SgN3j9jMbcZuiyrSnISz9',
#   'uri': 'spotify:track:1SgN3j9jMbcZuiyrSnISz9',
#   'track_href': 'https://api.spotify.com/v1/tracks/1SgN3j9jMbcZuiyrSnISz9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SgN3j9jMbcZuiyrSnISz9',
#   'duration_ms': 236924,
#   'time_signature': 4},
#  {'danceability': 0.546,
#   'energy': 0.646,
#   'key': 0,
#   'loudness': -9.389,
#   'mode': 1,
#   'speechiness': 0.0407,
#   'acousticness': 0.0864,
#   'instrumentalness': 0.882,
#   'liveness': 0.117,
#   'valence': 0.428,
#   'tempo': 106.004,
#   'type': 'audio_features',
#   'id': '50NbWayQdJBN6bOMAX6ToV',
#   'uri': 'spotify:track:50NbWayQdJBN6bOMAX6ToV',
#   'track_href': 'https://api.spotify.com/v1/tracks/50NbWayQdJBN6bOMAX6ToV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50NbWayQdJBN6bOMAX6ToV',
#   'duration_ms': 287933,
#   'time_signature': 4},
#  {'danceability': 0.707,
#   'energy': 0.533,
#   'key': 9,
#   'loudness': -5.794,
#   'mode': 0,
#   'speechiness': 0.0416,
#   'acousticness': 0.553,
#   'instrumentalness': 0,
#   'liveness': 0.0926,
#   'valence': 0.472,
#   'tempo': 94.987,
#   'type': 'audio_features',
#   'id': '0EYKD5N0mldDeVTCzCfzqr',
#   'uri': 'spotify:track:0EYKD5N0mldDeVTCzCfzqr',
#   'track_href': 'https://api.spotify.com/v1/tracks/0EYKD5N0mldDeVTCzCfzqr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0EYKD5N0mldDeVTCzCfzqr',
#   'duration_ms': 224526,
#   'time_signature': 4},
#  {'danceability': 0.496,
#   'energy': 0.72,
#   'key': 0,
#   'loudness': -8.74,
#   'mode': 1,
#   'speechiness': 0.0396,
#   'acousticness': 0.00119,
#   'instrumentalness': 0.026,
#   'liveness': 0.123,
#   'valence': 0.583,
#   'tempo': 124.772,
#   'type': 'audio_features',
#   'id': '6ZtUudtvm3fmY1lH7DUyOI',
#   'uri': 'spotify:track:6ZtUudtvm3fmY1lH7DUyOI',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ZtUudtvm3fmY1lH7DUyOI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ZtUudtvm3fmY1lH7DUyOI',
#   'duration_ms': 172560,
#   'time_signature': 4},
#  {'danceability': 0.463,
#   'energy': 0.576,
#   'key': 8,
#   'loudness': -4.888,
#   'mode': 1,
#   'speechiness': 0.0365,
#   'acousticness': 0.0203,
#   'instrumentalness': 0.000149,
#   'liveness': 0.12,
#   'valence': 0.0726,
#   'tempo': 122.902,
#   'type': 'audio_features',
#   'id': '0Z8A6Kg5RNijfaRoGF2p64',
#   'uri': 'spotify:track:0Z8A6Kg5RNijfaRoGF2p64',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Z8A6Kg5RNijfaRoGF2p64',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Z8A6Kg5RNijfaRoGF2p64',
#   'duration_ms': 234027,
#   'time_signature': 4},
#  {'danceability': 0.632,
#   'energy': 0.723,
#   'key': 10,
#   'loudness': -10.204,
#   'mode': 0,
#   'speechiness': 0.0414,
#   'acousticness': 0.746,
#   'instrumentalness': 4.24e-06,
#   'liveness': 0.333,
#   'valence': 0.961,
#   'tempo': 130.292,
#   'type': 'audio_features',
#   'id': '4UncGeJfZIIhAuXbINRf5E',
#   'uri': 'spotify:track:4UncGeJfZIIhAuXbINRf5E',
#   'track_href': 'https://api.spotify.com/v1/tracks/4UncGeJfZIIhAuXbINRf5E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4UncGeJfZIIhAuXbINRf5E',
#   'duration_ms': 114800,
#   'time_signature': 4},
#  {'danceability': 0.782,
#   'energy': 0.849,
#   'key': 2,
#   'loudness': -6.663,
#   'mode': 0,
#   'speechiness': 0.0381,
#   'acousticness': 0.49,
#   'instrumentalness': 0.0103,
#   'liveness': 0.121,
#   'valence': 0.827,
#   'tempo': 116.384,
#   'type': 'audio_features',
#   'id': '6SFCvojUWUqdWldrwVbOOT',
#   'uri': 'spotify:track:6SFCvojUWUqdWldrwVbOOT',
#   'track_href': 'https://api.spotify.com/v1/tracks/6SFCvojUWUqdWldrwVbOOT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SFCvojUWUqdWldrwVbOOT',
#   'duration_ms': 302840,
#   'time_signature': 4},
#  {'danceability': 0.601,
#   'energy': 0.941,
#   'key': 11,
#   'loudness': -3.022,
#   'mode': 0,
#   'speechiness': 0.0769,
#   'acousticness': 0.0858,
#   'instrumentalness': 8.63e-05,
#   'liveness': 0.881,
#   'valence': 0.703,
#   'tempo': 133.737,
#   'type': 'audio_features',
#   'id': '0BzPIlaQ5NGAWXmYcGxjwW',
#   'uri': 'spotify:track:0BzPIlaQ5NGAWXmYcGxjwW',
#   'track_href': 'https://api.spotify.com/v1/tracks/0BzPIlaQ5NGAWXmYcGxjwW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BzPIlaQ5NGAWXmYcGxjwW',
#   'duration_ms': 267053,
#   'time_signature': 4},
#  {'danceability': 0.543,
#   'energy': 0.751,
#   'key': 11,
#   'loudness': -8.824,
#   'mode': 0,
#   'speechiness': 0.0391,
#   'acousticness': 0.0176,
#   'instrumentalness': 0.611,
#   'liveness': 0.143,
#   'valence': 0.411,
#   'tempo': 100.929,
#   'type': 'audio_features',
#   'id': '5M6hQO5GP9LiOX1mDnCkfB',
#   'uri': 'spotify:track:5M6hQO5GP9LiOX1mDnCkfB',
#   'track_href': 'https://api.spotify.com/v1/tracks/5M6hQO5GP9LiOX1mDnCkfB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5M6hQO5GP9LiOX1mDnCkfB',
#   'duration_ms': 236554,
#   'time_signature': 4},
#  {'danceability': 0.51,
#   'energy': 0.868,
#   'key': 3,
#   'loudness': -15.156,
#   'mode': 0,
#   'speechiness': 0.074,
#   'acousticness': 0.0508,
#   'instrumentalness': 0.288,
#   'liveness': 0.703,
#   'valence': 0.557,
#   'tempo': 110.947,
#   'type': 'audio_features',
#   'id': '3LcupwswRKl1ksF8moWX9H',
#   'uri': 'spotify:track:3LcupwswRKl1ksF8moWX9H',
#   'track_href': 'https://api.spotify.com/v1/tracks/3LcupwswRKl1ksF8moWX9H',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3LcupwswRKl1ksF8moWX9H',
#   'duration_ms': 313160,
#   'time_signature': 4},
#  {'danceability': 0.302,
#   'energy': 0.701,
#   'key': 9,
#   'loudness': -5.759,
#   'mode': 1,
#   'speechiness': 0.0484,
#   'acousticness': 0.317,
#   'instrumentalness': 0.0242,
#   'liveness': 0.264,
#   'valence': 0.375,
#   'tempo': 87.305,
#   'type': 'audio_features',
#   'id': '6rDeD5wQ1vcAMG2SpQOPed',
#   'uri': 'spotify:track:6rDeD5wQ1vcAMG2SpQOPed',
#   'track_href': 'https://api.spotify.com/v1/tracks/6rDeD5wQ1vcAMG2SpQOPed',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6rDeD5wQ1vcAMG2SpQOPed',
#   'duration_ms': 503000,
#   'time_signature': 4},
#  {'danceability': 0.584,
#   'energy': 0.733,
#   'key': 0,
#   'loudness': -7.246,
#   'mode': 1,
#   'speechiness': 0.04,
#   'acousticness': 0.0141,
#   'instrumentalness': 0.0132,
#   'liveness': 0.11,
#   'valence': 0.708,
#   'tempo': 121.948,
#   'type': 'audio_features',
#   'id': '25zeHP11go4rGsTdMmrQI7',
#   'uri': 'spotify:track:25zeHP11go4rGsTdMmrQI7',
#   'track_href': 'https://api.spotify.com/v1/tracks/25zeHP11go4rGsTdMmrQI7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25zeHP11go4rGsTdMmrQI7',
#   'duration_ms': 211480,
#   'time_signature': 4},
#  {'danceability': 0.494,
#   'energy': 0.325,
#   'key': 7,
#   'loudness': -13.474,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.692,
#   'instrumentalness': 0,
#   'liveness': 0.304,
#   'valence': 0.96,
#   'tempo': 161.181,
#   'type': 'audio_features',
#   'id': '5GfBJkcVh9BYrmTssKuO2n',
#   'uri': 'spotify:track:5GfBJkcVh9BYrmTssKuO2n',
#   'track_href': 'https://api.spotify.com/v1/tracks/5GfBJkcVh9BYrmTssKuO2n',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5GfBJkcVh9BYrmTssKuO2n',
#   'duration_ms': 125173,
#   'time_signature': 4},
#  {'danceability': 0.71,
#   'energy': 0.584,
#   'key': 8,
#   'loudness': -7.64,
#   'mode': 0,
#   'speechiness': 0.0267,
#   'acousticness': 0.577,
#   'instrumentalness': 0.00287,
#   'liveness': 0.149,
#   'valence': 0.555,
#   'tempo': 113.016,
#   'type': 'audio_features',
#   'id': '1ZWbfmoCmTmEFf02hCw2tS',
#   'uri': 'spotify:track:1ZWbfmoCmTmEFf02hCw2tS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ZWbfmoCmTmEFf02hCw2tS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ZWbfmoCmTmEFf02hCw2tS',
#   'duration_ms': 265036,
#   'time_signature': 4},
#  {'danceability': 0.579,
#   'energy': 0.477,
#   'key': 2,
#   'loudness': -10.853,
#   'mode': 1,
#   'speechiness': 0.0345,
#   'acousticness': 0.00611,
#   'instrumentalness': 8.87e-06,
#   'liveness': 0.38,
#   'valence': 0.527,
#   'tempo': 137.923,
#   'type': 'audio_features',
#   'id': '2ENmfywUgnGAyhAK9yLvLz',
#   'uri': 'spotify:track:2ENmfywUgnGAyhAK9yLvLz',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ENmfywUgnGAyhAK9yLvLz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ENmfywUgnGAyhAK9yLvLz',
#   'duration_ms': 171733,
#   'time_signature': 4},
#  {'danceability': 0.39,
#   'energy': 0.645,
#   'key': 0,
#   'loudness': -8.03,
#   'mode': 1,
#   'speechiness': 0.0289,
#   'acousticness': 0.0406,
#   'instrumentalness': 0.00107,
#   'liveness': 0.134,
#   'valence': 0.471,
#   'tempo': 76.974,
#   'type': 'audio_features',
#   'id': '0aiMklluzV7MN7nCrz6Up1',
#   'uri': 'spotify:track:0aiMklluzV7MN7nCrz6Up1',
#   'track_href': 'https://api.spotify.com/v1/tracks/0aiMklluzV7MN7nCrz6Up1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0aiMklluzV7MN7nCrz6Up1',
#   'duration_ms': 184507,
#   'time_signature': 4},
#  {'danceability': 0.249,
#   'energy': 0.739,
#   'key': 0,
#   'loudness': -8.07,
#   'mode': 0,
#   'speechiness': 0.0373,
#   'acousticness': 0.0455,
#   'instrumentalness': 0.00432,
#   'liveness': 0.232,
#   'valence': 0.566,
#   'tempo': 215.994,
#   'type': 'audio_features',
#   'id': '3AP16mgHpBvJQ8wA389X66',
#   'uri': 'spotify:track:3AP16mgHpBvJQ8wA389X66',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AP16mgHpBvJQ8wA389X66',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AP16mgHpBvJQ8wA389X66',
#   'duration_ms': 204067,
#   'time_signature': 4},
#  {'danceability': 0.806,
#   'energy': 0.788,
#   'key': 0,
#   'loudness': -12.398,
#   'mode': 1,
#   'speechiness': 0.0626,
#   'acousticness': 0.115,
#   'instrumentalness': 0.00273,
#   'liveness': 0.132,
#   'valence': 0.571,
#   'tempo': 124.077,
#   'type': 'audio_features',
#   'id': '6Oz9XfeBlYgbwX8BN4uvQn',
#   'uri': 'spotify:track:6Oz9XfeBlYgbwX8BN4uvQn',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Oz9XfeBlYgbwX8BN4uvQn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Oz9XfeBlYgbwX8BN4uvQn',
#   'duration_ms': 205733,
#   'time_signature': 4},
#  {'danceability': 0.839,
#   'energy': 0.508,
#   'key': 1,
#   'loudness': -12.359,
#   'mode': 1,
#   'speechiness': 0.219,
#   'acousticness': 0.0126,
#   'instrumentalness': 3.06e-05,
#   'liveness': 0.0928,
#   'valence': 0.874,
#   'tempo': 80.014,
#   'type': 'audio_features',
#   'id': '6JvodgYcsthsORxPsEYUoe',
#   'uri': 'spotify:track:6JvodgYcsthsORxPsEYUoe',
#   'track_href': 'https://api.spotify.com/v1/tracks/6JvodgYcsthsORxPsEYUoe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JvodgYcsthsORxPsEYUoe',
#   'duration_ms': 206893,
#   'time_signature': 4},
#  {'danceability': 0.884,
#   'energy': 0.37,
#   'key': 8,
#   'loudness': -11.353,
#   'mode': 1,
#   'speechiness': 0.112,
#   'acousticness': 0.0188,
#   'instrumentalness': 0.00423,
#   'liveness': 0.026,
#   'valence': 0.883,
#   'tempo': 109.997,
#   'type': 'audio_features',
#   'id': '5DOYik1z3Of1wAFfY3dYbC',
#   'uri': 'spotify:track:5DOYik1z3Of1wAFfY3dYbC',
#   'track_href': 'https://api.spotify.com/v1/tracks/5DOYik1z3Of1wAFfY3dYbC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5DOYik1z3Of1wAFfY3dYbC',
#   'duration_ms': 247507,
#   'time_signature': 4},
#  {'danceability': 0.822,
#   'energy': 0.661,
#   'key': 1,
#   'loudness': -10.234,
#   'mode': 0,
#   'speechiness': 0.164,
#   'acousticness': 0.0241,
#   'instrumentalness': 3.95e-06,
#   'liveness': 0.315,
#   'valence': 0.67,
#   'tempo': 99.883,
#   'type': 'audio_features',
#   'id': '1aaoIHFT9UqhlaEwLAhh00',
#   'uri': 'spotify:track:1aaoIHFT9UqhlaEwLAhh00',
#   'track_href': 'https://api.spotify.com/v1/tracks/1aaoIHFT9UqhlaEwLAhh00',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1aaoIHFT9UqhlaEwLAhh00',
#   'duration_ms': 272707,
#   'time_signature': 4},
#  {'danceability': 0.307,
#   'energy': 0.744,
#   'key': 6,
#   'loudness': -11.687,
#   'mode': 1,
#   'speechiness': 0.072,
#   'acousticness': 0.0254,
#   'instrumentalness': 0.00463,
#   'liveness': 0.0946,
#   'valence': 0.303,
#   'tempo': 108.874,
#   'type': 'audio_features',
#   'id': '6YLkm72GWcUeFxcmnEdfel',
#   'uri': 'spotify:track:6YLkm72GWcUeFxcmnEdfel',
#   'track_href': 'https://api.spotify.com/v1/tracks/6YLkm72GWcUeFxcmnEdfel',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6YLkm72GWcUeFxcmnEdfel',
#   'duration_ms': 277920,
#   'time_signature': 4},
#  {'danceability': 0.689,
#   'energy': 0.721,
#   'key': 2,
#   'loudness': -7.667,
#   'mode': 1,
#   'speechiness': 0.0996,
#   'acousticness': 0.538,
#   'instrumentalness': 0.000354,
#   'liveness': 0.0802,
#   'valence': 0.87,
#   'tempo': 80.007,
#   'type': 'audio_features',
#   'id': '15GQCzXREL0v7zoWNQhyfF',
#   'uri': 'spotify:track:15GQCzXREL0v7zoWNQhyfF',
#   'track_href': 'https://api.spotify.com/v1/tracks/15GQCzXREL0v7zoWNQhyfF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15GQCzXREL0v7zoWNQhyfF',
#   'duration_ms': 283410,
#   'time_signature': 4},
#  {'danceability': 0.736,
#   'energy': 0.861,
#   'key': 4,
#   'loudness': -6.116,
#   'mode': 0,
#   'speechiness': 0.062,
#   'acousticness': 0.0714,
#   'instrumentalness': 0.335,
#   'liveness': 0.0672,
#   'valence': 0.876,
#   'tempo': 113.472,
#   'type': 'audio_features',
#   'id': '1zS4vAwpfubhqqePjNFXkr',
#   'uri': 'spotify:track:1zS4vAwpfubhqqePjNFXkr',
#   'track_href': 'https://api.spotify.com/v1/tracks/1zS4vAwpfubhqqePjNFXkr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zS4vAwpfubhqqePjNFXkr',
#   'duration_ms': 182520,
#   'time_signature': 4},
#  {'danceability': 0.442,
#   'energy': 0.359,
#   'key': 9,
#   'loudness': -11.451,
#   'mode': 1,
#   'speechiness': 0.0277,
#   'acousticness': 0.714,
#   'instrumentalness': 0.00804,
#   'liveness': 0.192,
#   'valence': 0.202,
#   'tempo': 79.348,
#   'type': 'audio_features',
#   'id': '7ilx8YTc6Nmg9fAMrySaAg',
#   'uri': 'spotify:track:7ilx8YTc6Nmg9fAMrySaAg',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ilx8YTc6Nmg9fAMrySaAg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ilx8YTc6Nmg9fAMrySaAg',
#   'duration_ms': 181160,
#   'time_signature': 4},
#  {'danceability': 0.416,
#   'energy': 0.398,
#   'key': 10,
#   'loudness': -10.981,
#   'mode': 1,
#   'speechiness': 0.0471,
#   'acousticness': 0.657,
#   'instrumentalness': 1.25e-06,
#   'liveness': 0.121,
#   'valence': 0.264,
#   'tempo': 69.387,
#   'type': 'audio_features',
#   'id': '5Va4EmNp4g8lniR5MiR4oT',
#   'uri': 'spotify:track:5Va4EmNp4g8lniR5MiR4oT',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Va4EmNp4g8lniR5MiR4oT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Va4EmNp4g8lniR5MiR4oT',
#   'duration_ms': 209688,
#   'time_signature': 3},
#  {'danceability': 0.831,
#   'energy': 0.65,
#   'key': 9,
#   'loudness': -4.508,
#   'mode': 1,
#   'speechiness': 0.0601,
#   'acousticness': 0.155,
#   'instrumentalness': 0.262,
#   'liveness': 0.105,
#   'valence': 0.826,
#   'tempo': 101.681,
#   'type': 'audio_features',
#   'id': '7LOAChK8Lkj8ZdF1LuhNWP',
#   'uri': 'spotify:track:7LOAChK8Lkj8ZdF1LuhNWP',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LOAChK8Lkj8ZdF1LuhNWP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LOAChK8Lkj8ZdF1LuhNWP',
#   'duration_ms': 152867,
#   'time_signature': 4},
#  {'danceability': 0.544,
#   'energy': 0.696,
#   'key': 2,
#   'loudness': -6.144,
#   'mode': 0,
#   'speechiness': 0.0333,
#   'acousticness': 0.05,
#   'instrumentalness': 2.62e-05,
#   'liveness': 0.0798,
#   'valence': 0.587,
#   'tempo': 167.686,
#   'type': 'audio_features',
#   'id': '7dDqBcBTZAxF0uxkWw4n8w',
#   'uri': 'spotify:track:7dDqBcBTZAxF0uxkWw4n8w',
#   'track_href': 'https://api.spotify.com/v1/tracks/7dDqBcBTZAxF0uxkWw4n8w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7dDqBcBTZAxF0uxkWw4n8w',
#   'duration_ms': 219413,
#   'time_signature': 4},
#  {'danceability': 0.536,
#   'energy': 0.606,
#   'key': 7,
#   'loudness': -5.364,
#   'mode': 1,
#   'speechiness': 0.0355,
#   'acousticness': 0.103,
#   'instrumentalness': 1.08e-05,
#   'liveness': 0.255,
#   'valence': 0.719,
#   'tempo': 146.425,
#   'type': 'audio_features',
#   'id': '3q2gRjU2UdOYRDY1p4cNHr',
#   'uri': 'spotify:track:3q2gRjU2UdOYRDY1p4cNHr',
#   'track_href': 'https://api.spotify.com/v1/tracks/3q2gRjU2UdOYRDY1p4cNHr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3q2gRjU2UdOYRDY1p4cNHr',
#   'duration_ms': 206267,
#   'time_signature': 4},
#  {'danceability': 0.663,
#   'energy': 0.617,
#   'key': 9,
#   'loudness': -5.093,
#   'mode': 0,
#   'speechiness': 0.0369,
#   'acousticness': 0.252,
#   'instrumentalness': 0,
#   'liveness': 0.114,
#   'valence': 0.909,
#   'tempo': 122.953,
#   'type': 'audio_features',
#   'id': '2LdDI7htwPD82owhVPylvA',
#   'uri': 'spotify:track:2LdDI7htwPD82owhVPylvA',
#   'track_href': 'https://api.spotify.com/v1/tracks/2LdDI7htwPD82owhVPylvA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2LdDI7htwPD82owhVPylvA',
#   'duration_ms': 257893,
#   'time_signature': 4},
#  {'danceability': 0.341,
#   'energy': 0.118,
#   'key': 9,
#   'loudness': -16.88,
#   'mode': 0,
#   'speechiness': 0.0467,
#   'acousticness': 0.989,
#   'instrumentalness': 0.259,
#   'liveness': 0.0944,
#   'valence': 0.0482,
#   'tempo': 169.403,
#   'type': 'audio_features',
#   'id': '1WzbFKytvAHTmbnGwtiIw3',
#   'uri': 'spotify:track:1WzbFKytvAHTmbnGwtiIw3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1WzbFKytvAHTmbnGwtiIw3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1WzbFKytvAHTmbnGwtiIw3',
#   'duration_ms': 197560,
#   'time_signature': 4},
#  {'danceability': 0.859,
#   'energy': 0.673,
#   'key': 9,
#   'loudness': -11.141,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.00796,
#   'instrumentalness': 0.138,
#   'liveness': 0.117,
#   'valence': 0.858,
#   'tempo': 119.406,
#   'type': 'audio_features',
#   'id': '1NXvMzcaELhxVOo87LUXYd',
#   'uri': 'spotify:track:1NXvMzcaELhxVOo87LUXYd',
#   'track_href': 'https://api.spotify.com/v1/tracks/1NXvMzcaELhxVOo87LUXYd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1NXvMzcaELhxVOo87LUXYd',
#   'duration_ms': 303700,
#   'time_signature': 4},
#  {'danceability': 0.739,
#   'energy': 0.799,
#   'key': 5,
#   'loudness': -9.402,
#   'mode': 1,
#   'speechiness': 0.0482,
#   'acousticness': 0.203,
#   'instrumentalness': 2.72e-06,
#   'liveness': 0.174,
#   'valence': 0.962,
#   'tempo': 128.019,
#   'type': 'audio_features',
#   'id': '4gPO2nAc66y47KYbiCj1DT',
#   'uri': 'spotify:track:4gPO2nAc66y47KYbiCj1DT',
#   'track_href': 'https://api.spotify.com/v1/tracks/4gPO2nAc66y47KYbiCj1DT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4gPO2nAc66y47KYbiCj1DT',
#   'duration_ms': 221400,
#   'time_signature': 4},
#  {'danceability': 0.749,
#   'energy': 0.332,
#   'key': 0,
#   'loudness': -7.574,
#   'mode': 1,
#   'speechiness': 0.0534,
#   'acousticness': 0.0207,
#   'instrumentalness': 0.911,
#   'liveness': 0.168,
#   'valence': 0.376,
#   'tempo': 119.993,
#   'type': 'audio_features',
#   'id': '4lKA7msPm2tcRStLLcIqd8',
#   'uri': 'spotify:track:4lKA7msPm2tcRStLLcIqd8',
#   'track_href': 'https://api.spotify.com/v1/tracks/4lKA7msPm2tcRStLLcIqd8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4lKA7msPm2tcRStLLcIqd8',
#   'duration_ms': 351000,
#   'time_signature': 4},
#  {'danceability': 0.529,
#   'energy': 0.651,
#   'key': 4,
#   'loudness': -8.861,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.00275,
#   'instrumentalness': 0.842,
#   'liveness': 0.119,
#   'valence': 0.548,
#   'tempo': 108.078,
#   'type': 'audio_features',
#   'id': '1gBCMFjPpukTeRhAshfPiu',
#   'uri': 'spotify:track:1gBCMFjPpukTeRhAshfPiu',
#   'track_href': 'https://api.spotify.com/v1/tracks/1gBCMFjPpukTeRhAshfPiu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1gBCMFjPpukTeRhAshfPiu',
#   'duration_ms': 239707,
#   'time_signature': 4},
#  {'danceability': 0.768,
#   'energy': 0.696,
#   'key': 7,
#   'loudness': -7.982,
#   'mode': 1,
#   'speechiness': 0.0519,
#   'acousticness': 0.0511,
#   'instrumentalness': 0.000127,
#   'liveness': 0.154,
#   'valence': 0.885,
#   'tempo': 130.094,
#   'type': 'audio_features',
#   'id': '7wPoCwDNHNcJHG0baZNVnN',
#   'uri': 'spotify:track:7wPoCwDNHNcJHG0baZNVnN',
#   'track_href': 'https://api.spotify.com/v1/tracks/7wPoCwDNHNcJHG0baZNVnN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7wPoCwDNHNcJHG0baZNVnN',
#   'duration_ms': 206600,
#   'time_signature': 4},
#  {'danceability': 0.797,
#   'energy': 0.63,
#   'key': 4,
#   'loudness': -10.742,
#   'mode': 0,
#   'speechiness': 0.137,
#   'acousticness': 0.00794,
#   'instrumentalness': 0.173,
#   'liveness': 0.198,
#   'valence': 0.301,
#   'tempo': 98.207,
#   'type': 'audio_features',
#   'id': '7vaGequwI1SWTKGJes1ey7',
#   'uri': 'spotify:track:7vaGequwI1SWTKGJes1ey7',
#   'track_href': 'https://api.spotify.com/v1/tracks/7vaGequwI1SWTKGJes1ey7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7vaGequwI1SWTKGJes1ey7',
#   'duration_ms': 428467,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.693,
#   'key': 7,
#   'loudness': -8.08,
#   'mode': 0,
#   'speechiness': 0.0436,
#   'acousticness': 0.162,
#   'instrumentalness': 5.7e-06,
#   'liveness': 0.263,
#   'valence': 0.825,
#   'tempo': 115.516,
#   'type': 'audio_features',
#   'id': '4A6GfgTVvJOnZPLHta1jXM',
#   'uri': 'spotify:track:4A6GfgTVvJOnZPLHta1jXM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4A6GfgTVvJOnZPLHta1jXM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4A6GfgTVvJOnZPLHta1jXM',
#   'duration_ms': 249293,
#   'time_signature': 4},
#  {'danceability': 0.663,
#   'energy': 0.974,
#   'key': 10,
#   'loudness': -3.866,
#   'mode': 0,
#   'speechiness': 0.0669,
#   'acousticness': 0.118,
#   'instrumentalness': 0.108,
#   'liveness': 0.0191,
#   'valence': 0.577,
#   'tempo': 127.907,
#   'type': 'audio_features',
#   'id': '755gfYHSMoS4kPEJLRM3Lo',
#   'uri': 'spotify:track:755gfYHSMoS4kPEJLRM3Lo',
#   'track_href': 'https://api.spotify.com/v1/tracks/755gfYHSMoS4kPEJLRM3Lo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/755gfYHSMoS4kPEJLRM3Lo',
#   'duration_ms': 493213,
#   'time_signature': 4},
#  {'danceability': 0.808,
#   'energy': 0.914,
#   'key': 0,
#   'loudness': -6.242,
#   'mode': 1,
#   'speechiness': 0.0704,
#   'acousticness': 0.0441,
#   'instrumentalness': 0.0793,
#   'liveness': 0.143,
#   'valence': 0.919,
#   'tempo': 123.973,
#   'type': 'audio_features',
#   'id': '5PL9tfATuCPcAg6oOIdC21',
#   'uri': 'spotify:track:5PL9tfATuCPcAg6oOIdC21',
#   'track_href': 'https://api.spotify.com/v1/tracks/5PL9tfATuCPcAg6oOIdC21',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PL9tfATuCPcAg6oOIdC21',
#   'duration_ms': 179027,
#   'time_signature': 4}]

# %%
# Convert audio features list (of dict) to a dataframe. Because we can merge it with the track name, artist name dataframe we have created above in the next step
audio_features_df = pd.DataFrame(audio_features)
audio_features_df.head(50)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.508000    0.1190   0.9610  105.796  audio_features
# 1           0.000402    0.0888   0.9360  129.957  audio_features
# 2           0.000002    0.0859   0.9310  129.549  audio_features
# 3           0.116000    0.0451   0.6680  116.938  audio_features
# 4           0.922000    0.0744   0.7430  126.009  audio_features
# 5           0.016700    0.0602   0.8210  204.397  audio_features
# 6           0.602000    0.1110   0.0343   97.059  audio_features
# 7           0.072400    0.0824   0.8780  136.568  audio_features
# 8           0.055900    0.3500   0.8140  112.014  audio_features
# 9           0.000000    0.6290   0.5270   99.074  audio_features
# 10          0.000803    0.1290   0.2530  125.981  audio_features
# 11          0.882000    0.1170   0.4280  106.004  audio_features
# 12          0.000000    0.0926   0.4720   94.987  audio_features
# 13          0.026000    0.1230   0.5830  124.772  audio_features
# 14          0.000149    0.1200   0.0726  122.902  audio_features
# 15          0.000004    0.3330   0.9610  130.292  audio_features
# 16          0.010300    0.1210   0.8270  116.384  audio_features
# 17          0.000086    0.8810   0.7030  133.737  audio_features
# 18          0.611000    0.1430   0.4110  100.929  audio_features
# 19          0.288000    0.7030   0.5570  110.947  audio_features
# 20          0.024200    0.2640   0.3750   87.305  audio_features
# 21          0.013200    0.1100   0.7080  121.948  audio_features
# 22          0.000000    0.3040   0.9600  161.181  audio_features
# 23          0.002870    0.1490   0.5550  113.016  audio_features
# 24          0.000009    0.3800   0.5270  137.923  audio_features
# 25          0.001070    0.1340   0.4710   76.974  audio_features
# 26          0.004320    0.2320   0.5660  215.994  audio_features
# 27          0.002730    0.1320   0.5710  124.077  audio_features
# 28          0.000031    0.0928   0.8740   80.014  audio_features
# 29          0.004230    0.0260   0.8830  109.997  audio_features
# 30          0.000004    0.3150   0.6700   99.883  audio_features
# 31          0.004630    0.0946   0.3030  108.874  audio_features
# 32          0.000354    0.0802   0.8700   80.007  audio_features
# 33          0.335000    0.0672   0.8760  113.472  audio_features
# 34          0.008040    0.1920   0.2020   79.348  audio_features
# 35          0.000001    0.1210   0.2640   69.387  audio_features
# 36          0.262000    0.1050   0.8260  101.681  audio_features
# 37          0.000026    0.0798   0.5870  167.686  audio_features
# 38          0.000011    0.2550   0.7190  146.425  audio_features
# 39          0.000000    0.1140   0.9090  122.953  audio_features
# 40          0.259000    0.0944   0.0482  169.403  audio_features
# 41          0.138000    0.1170   0.8580  119.406  audio_features
# 42          0.000003    0.1740   0.9620  128.019  audio_features
# 43          0.911000    0.1680   0.3760  119.993  audio_features
# 44          0.842000    0.1190   0.5480  108.078  audio_features
# 45          0.000127    0.1540   0.8850  130.094  audio_features
# 46          0.173000    0.1980   0.3010   98.207  audio_features
# 47          0.000006    0.2630   0.8250  115.516  audio_features
# 48          0.108000    0.0191   0.5770  127.907  audio_features
# 49          0.079300    0.1430   0.9190  123.973  audio_features
#
#                         id                                   uri  \
# 0   6DPdkuilLYzkZIGr53HsrG  spotify:track:6DPdkuilLYzkZIGr53HsrG
# 1   6puSkh7Unbn3avNFvZMZz1  spotify:track:6puSkh7Unbn3avNFvZMZz1
# 2   33g1XVNgo3lbDLeRiRQ0TL  spotify:track:33g1XVNgo3lbDLeRiRQ0TL
# 3   4Q8b1l8daZE9ALzkd6kKzL  spotify:track:4Q8b1l8daZE9ALzkd6kKzL
# 4   1yzgJNsnTGZacmsrcvZL4V  spotify:track:1yzgJNsnTGZacmsrcvZL4V
# 35  5Va4EmNp4g8lniR5MiR4oT  spotify:track:5Va4EmNp4g8lniR5MiR4oT
# 36  7LOAChK8Lkj8ZdF1LuhNWP  spotify:track:7LOAChK8Lkj8ZdF1LuhNWP
# 37  7dDqBcBTZAxF0uxkWw4n8w  spotify:track:7dDqBcBTZAxF0uxkWw4n8w
# 38  3q2gRjU2UdOYRDY1p4cNHr  spotify:track:3q2gRjU2UdOYRDY1p4cNHr
# 39  2LdDI7htwPD82owhVPylvA  spotify:track:2LdDI7htwPD82owhVPylvA
# 40  1WzbFKytvAHTmbnGwtiIw3  spotify:track:1WzbFKytvAHTmbnGwtiIw3
# 41  1NXvMzcaELhxVOo87LUXYd  spotify:track:1NXvMzcaELhxVOo87LUXYd
# 42  4gPO2nAc66y47KYbiCj1DT  spotify:track:4gPO2nAc66y47KYbiCj1DT
# 43  4lKA7msPm2tcRStLLcIqd8  spotify:track:4lKA7msPm2tcRStLLcIqd8
# 44  1gBCMFjPpukTeRhAshfPiu  spotify:track:1gBCMFjPpukTeRhAshfPiu
# 45  7wPoCwDNHNcJHG0baZNVnN  spotify:track:7wPoCwDNHNcJHG0baZNVnN
# 46  7vaGequwI1SWTKGJes1ey7  spotify:track:7vaGequwI1SWTKGJes1ey7
# 47  4A6GfgTVvJOnZPLHta1jXM  spotify:track:4A6GfgTVvJOnZPLHta1jXM
# 48  755gfYHSMoS4kPEJLRM3Lo  spotify:track:755gfYHSMoS4kPEJLRM3Lo
# 49  5PL9tfATuCPcAg6oOIdC21  spotify:track:5PL9tfATuCPcAg6oOIdC21
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/6DPdkuilLYzk...
# 1   https://api.spotify.com/v1/tracks/6puSkh7Unbn3...
# 2   https://api.spotify.com/v1/tracks/33g1XVNgo3lb...
# 3   https://api.spotify.com/v1/tracks/4Q8b1l8daZE9...
# 4   https://api.spotify.com/v1/tracks/1yzgJNsnTGZa...
# 5   https://api.spotify.com/v1/tracks/5M5ySjWYS4s6...
# 6   https://api.spotify.com/v1/tracks/61t7MU96q1DW...
# 7   https://api.spotify.com/v1/tracks/5fPsQzd4GMMP...
# 8   https://api.spotify.com/v1/tracks/5UuVuVCEag2V...
# 9   https://api.spotify.com/v1/tracks/43ievcG8mUfV...
# 10  https://api.spotify.com/v1/tracks/1SgN3j9jMbcZ...
# 11  https://api.spotify.com/v1/tracks/50NbWayQdJBN...
# 12  https://api.spotify.com/v1/tracks/0EYKD5N0mldD...
# 13  https://api.spotify.com/v1/tracks/6ZtUudtvm3fm...
# 14  https://api.spotify.com/v1/tracks/0Z8A6Kg5RNij...
# 15  https://api.spotify.com/v1/tracks/4UncGeJfZIIh...
# 16  https://api.spotify.com/v1/tracks/6SFCvojUWUqd...
# 17  https://api.spotify.com/v1/tracks/0BzPIlaQ5NGA...
# 18  https://api.spotify.com/v1/tracks/5M6hQO5GP9Li...
# 19  https://api.spotify.com/v1/tracks/3LcupwswRKl1...
# 20  https://api.spotify.com/v1/tracks/6rDeD5wQ1vcA...
# 21  https://api.spotify.com/v1/tracks/25zeHP11go4r...
# 18  https://api.spotify.com/v1/audio-analysis/5M6h...       236554
# 19  https://api.spotify.com/v1/audio-analysis/3Lcu...       313160
# 20  https://api.spotify.com/v1/audio-analysis/6rDe...       503000
# 21  https://api.spotify.com/v1/audio-analysis/25ze...       211480
# 22  https://api.spotify.com/v1/audio-analysis/5GfB...       125173
# 23  https://api.spotify.com/v1/audio-analysis/1ZWb...       265036
# 24  https://api.spotify.com/v1/audio-analysis/2ENm...       171733
# 25  https://api.spotify.com/v1/audio-analysis/0aiM...       184507
# 26  https://api.spotify.com/v1/audio-analysis/3AP1...       204067
# 27  https://api.spotify.com/v1/audio-analysis/6Oz9...       205733
# 28  https://api.spotify.com/v1/audio-analysis/6Jvo...       206893
# 29  https://api.spotify.com/v1/audio-analysis/5DOY...       247507
# 30  https://api.spotify.com/v1/audio-analysis/1aao...       272707
# 31  https://api.spotify.com/v1/audio-analysis/6YLk...       277920
# 32  https://api.spotify.com/v1/audio-analysis/15GQ...       283410
# 33  https://api.spotify.com/v1/audio-analysis/1zS4...       182520
# 34  https://api.spotify.com/v1/audio-analysis/7ilx...       181160
# 35  https://api.spotify.com/v1/audio-analysis/5Va4...       209688
# 36  https://api.spotify.com/v1/audio-analysis/7LOA...       152867
# 37  https://api.spotify.com/v1/audio-analysis/7dDq...       219413
# 38  https://api.spotify.com/v1/audio-analysis/3q2g...       206267
# 39  https://api.spotify.com/v1/audio-analysis/2LdD...       257893
# 40  https://api.spotify.com/v1/audio-analysis/1Wzb...       197560
# 41  https://api.spotify.com/v1/audio-analysis/1NXv...       303700
# 42  https://api.spotify.com/v1/audio-analysis/4gPO...       221400
# 43  https://api.spotify.com/v1/audio-analysis/4lKA...       351000
# 44  https://api.spotify.com/v1/audio-analysis/1gBC...       239707
# 45  https://api.spotify.com/v1/audio-analysis/7wPo...       206600
# 46  https://api.spotify.com/v1/audio-analysis/7vaG...       428467
# 47  https://api.spotify.com/v1/audio-analysis/4A6G...       249293
# 48  https://api.spotify.com/v1/audio-analysis/755g...       493213
# 49  https://api.spotify.com/v1/audio-analysis/5PL9...       179027
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                3
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
# 12               4
# 13               4
# 14               4
# 15               4
# 16               4
# 17               4
# 18               4
# 19               4
# 20               4
# 21               4
# 22               4
# 23               4
# 24               4
# 25               4
# 26               4
# 27               4
# 28               4
# 29               4
# 30               4
# 31               4
# 32               4
# 33               4
# 34               4
# 35               3
# 36               4
# 37               4
# 38               4
# 39               4
# 40               4
# 41               4
# 42               4
# 43               4
# 44               4
# 45               4
# 46               4
# 47               4
# 48               4
# 49               4

# %%
# Now I am merging the original dataframe with audio features df. The common column between these two DF is uri, so audio features will be duplicated for every track in the original dataframe
df = pd.merge(track_df, audio_features_df)
print(df.shape)
df.head(10)
# Out:
# (8682, 20)
#                                 track_name                  artist_name  \
# 0       Hey Leroy, Your Mama's Calling You                 Jimmy Castor
# 1                               Bang, Bang                 Jimmy Castor
# 2                        All I Ever Wanted             The Human League
# 3  Big Time Sensuality - The Fluke Minimix                        Björk
# 4  Big Time Sensuality - The Fluke Minimix                        Fluke
# 5              Fata Morgana - Original Mix              Der Dritte Raum
# 6                           Bad Reputation  Joan Jett & the Blackhearts
# 7                                My Window                The Residents
# 8                     Winchester Cathedral                 Jimmy Castor
# 9                                    Donna                 Rubblebucket
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:6DPdkuilLYzkZIGr53HsrG         0.714   0.765    0    -9.380
# 1  spotify:track:6puSkh7Unbn3avNFvZMZz1         0.655   0.878    3    -9.544
# 2  spotify:track:33g1XVNgo3lbDLeRiRQ0TL         0.649   0.789    0    -9.466
# 3  spotify:track:4Q8b1l8daZE9ALzkd6kKzL         0.644   0.785    8    -8.642
# 4  spotify:track:4Q8b1l8daZE9ALzkd6kKzL         0.644   0.785    8    -8.642
# 5  spotify:track:1yzgJNsnTGZacmsrcvZL4V         0.810   0.658    2    -9.676
# 6  spotify:track:5M5ySjWYS4s6hi2pEvEwb5         0.385   0.975    6    -4.099
# 7  spotify:track:61t7MU96q1DWE8eXBsUGua         0.205   0.246    8   -16.175
# 8  spotify:track:5fPsQzd4GMMPt7qePOxnAX         0.756   0.803    2    -9.508
# 9  spotify:track:5UuVuVCEag2VYp8PdWB2eB         0.572   0.942   11    -3.660
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0406       0.41000          0.508000    0.1190   0.9610
# 1     1       0.0312       0.83300          0.000402    0.0888   0.9360
# 2     1       0.0264       0.00441          0.000002    0.0859   0.9310
# 3     1       0.0284       0.00032          0.116000    0.0451   0.6680
# 4     1       0.0284       0.00032          0.116000    0.0451   0.6680
# 5     1       0.0463       0.00348          0.922000    0.0744   0.7430
# 6     1       0.1920       0.00197          0.016700    0.0602   0.8210
# 7     1       0.0313       0.24500          0.602000    0.1110   0.0343
# 8     0       0.0956       0.42700          0.072400    0.0824   0.8780
# 9     0       0.0448       0.00280          0.055900    0.3500   0.8140
#
#      tempo            type                      id  \
# 0  105.796  audio_features  6DPdkuilLYzkZIGr53HsrG
# 1  129.957  audio_features  6puSkh7Unbn3avNFvZMZz1
# 2  129.549  audio_features  33g1XVNgo3lbDLeRiRQ0TL
# 3  116.938  audio_features  4Q8b1l8daZE9ALzkd6kKzL
# 4  116.938  audio_features  4Q8b1l8daZE9ALzkd6kKzL
# 5  126.009  audio_features  1yzgJNsnTGZacmsrcvZL4V
# 6  204.397  audio_features  5M5ySjWYS4s6hi2pEvEwb5
# 7   97.059  audio_features  61t7MU96q1DWE8eXBsUGua
# 8  136.568  audio_features  5fPsQzd4GMMPt7qePOxnAX
# 9  112.014  audio_features  5UuVuVCEag2VYp8PdWB2eB
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6DPdkuilLYzk...
# 1  https://api.spotify.com/v1/tracks/6puSkh7Unbn3...
# 2  https://api.spotify.com/v1/tracks/33g1XVNgo3lb...
# 3  https://api.spotify.com/v1/tracks/4Q8b1l8daZE9...
# 4  https://api.spotify.com/v1/tracks/4Q8b1l8daZE9...
# 5  https://api.spotify.com/v1/tracks/1yzgJNsnTGZa...
# 6  https://api.spotify.com/v1/tracks/5M5ySjWYS4s6...
# 7  https://api.spotify.com/v1/tracks/61t7MU96q1DW...
# 8  https://api.spotify.com/v1/tracks/5fPsQzd4GMMP...
# 9  https://api.spotify.com/v1/tracks/5UuVuVCEag2V...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6DPd...       148440
# 1  https://api.spotify.com/v1/audio-analysis/6puS...       188160
# 2  https://api.spotify.com/v1/audio-analysis/33g1...       234333
# 3  https://api.spotify.com/v1/audio-analysis/4Q8b...       293840
# 4  https://api.spotify.com/v1/audio-analysis/4Q8b...       293840
# 5  https://api.spotify.com/v1/audio-analysis/1yzg...       339524
# 6  https://api.spotify.com/v1/audio-analysis/5M5y...       170841
# 7  https://api.spotify.com/v1/audio-analysis/61t7...       320960
# 8  https://api.spotify.com/v1/audio-analysis/5fPs...       163800
# 9  https://api.spotify.com/v1/audio-analysis/5UuV...       213813
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               3
# 8               4
# 9               4

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Drop duplicates
df = df.drop_duplicates()
df.shape
# Out:
# (8682, 20)

# %%
df.to_csv('./spotify_audio_features.csv', index = False)
df.to_csv('./spotify_audio_features_8080.csv', index = False)

# %%
import glob
import os

# %%
files = os.path.join("/Users/ayeesha/ironhack/lab-web-scraping-single-page/spotify- api wrapper/csv_files", "spotify*.csv")
files
# Out:
# '/Users/ayeesha/ironhack/lab-web-scraping-single-page/spotify- api wrapper/csv_files/spotify*.csv'

# %%
files = glob.glob(files)

# %%
files
# Out:
# ['/Users/ayeesha/ironhack/lab-web-scraping-single-page/spotify- api wrapper/csv_files/spotify_audio_features.csv',
#  '/Users/ayeesha/ironhack/lab-web-scraping-single-page/spotify- api wrapper/csv_files/spotify_audio_features_8080.csv']

# %%
df_spotify = pd.concat(map(pd.read_csv, files), ignore_index=True)
display(df_spotify)
# Out:
#                    track_name           artist_name  \
# 0      Fetch The Bolt Cutters           Fiona Apple
# 1              I Know The End       Phoebe Bridgers
# 2         Holster Your Silver      Brian Johannesen
# 3                        Fire           Waxahatchee
# 4                 Count On Me       The Lone Bellow
# ...                       ...                   ...
# 26119            Stone Flower  Antônio Carlos Jobim
# 26120                 Old Man         Help Yourself
# 26121                Eldorado            Neil Young
# 26122           Rain In Spain             Sea Level
# 26123                Changin'    Brass Construction
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:4SdubskbLiOkpsIjRVVsya         0.485   0.488    0
# 1      spotify:track:3cr3oAP4bQFNjZBV7ElKaB         0.328   0.320    1
# 2      spotify:track:31fwgj2HIy7CnQCBfD2wZ5         0.246   0.334    7
# 3      spotify:track:2QUEBOSGpKpL6bzzbQiwwo         0.613   0.454    7
# 4      spotify:track:5sA7NCo4bHH9stpolSymvz         0.374   0.798    2
# ...                                     ...           ...     ...  ...
# 26119  spotify:track:5gKt31WKlTPGBtTVkfDIUG         0.579   0.345    9
# 26120  spotify:track:4VTgjtmey70UKd6Htb2yxI         0.509   0.234    7
# 26121  spotify:track:4D3qYj3LzPRUD6BOD3PGp6         0.719   0.403    9
# 26122  spotify:track:4jmpbm9CGmFXLq296WG5X5         0.526   0.754    4
# 26123  spotify:track:1YJHxl53keKuB8QywSlFhb         0.678   0.908    0
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -11.340     1       0.1710        0.5260          0.000020    0.0686
# 1       -10.282     1       0.0350        0.3240          0.019000    0.2340
# 2       -14.365     1       0.0307        0.0154          0.011600    0.1470
# 3       -11.808     1       0.0484        0.6810          0.000007    0.1370
# 4        -4.660     1       0.1110        0.0220          0.000006    0.4030
# ...         ...   ...          ...           ...               ...       ...
# 26119   -16.064     1       0.0438        0.2180          0.055200    0.0961
# 26120   -16.782     1       0.0337        0.2820          0.467000    0.1130
# 26121   -13.545     0       0.0270        0.0127          0.008090    0.2550
# 26122    -8.501     0       0.0353        0.1300          0.350000    0.3400
# 26123    -4.092     1       0.0937        0.0691          0.034700    0.0546
#
#        valence    tempo            type                      id  \
# 0        0.339  150.856  audio_features  4SdubskbLiOkpsIjRVVsya
# 1        0.259  111.453  audio_features  3cr3oAP4bQFNjZBV7ElKaB
# 2        0.234   81.330  audio_features  31fwgj2HIy7CnQCBfD2wZ5
# 3        0.196   85.075  audio_features  2QUEBOSGpKpL6bzzbQiwwo
# 4        0.311  152.058  audio_features  5sA7NCo4bHH9stpolSymvz
# ...        ...      ...             ...                     ...
# 26119    0.626   97.972  audio_features  5gKt31WKlTPGBtTVkfDIUG
# 26120    0.543  154.081  audio_features  4VTgjtmey70UKd6Htb2yxI
# 26121    0.489  108.257  audio_features  4D3qYj3LzPRUD6BOD3PGp6
# 26122    0.592  106.097  audio_features  4jmpbm9CGmFXLq296WG5X5
# 26123    0.879  111.410  audio_features  1YJHxl53keKuB8QywSlFhb
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/4SdubskbLiOk...
# 1      https://api.spotify.com/v1/tracks/3cr3oAP4bQFN...
# 2      https://api.spotify.com/v1/tracks/31fwgj2HIy7C...
# 3      https://api.spotify.com/v1/tracks/2QUEBOSGpKpL...
# 4      https://api.spotify.com/v1/tracks/5sA7NCo4bHH9...
# ...                                                  ...
# 26119  https://api.spotify.com/v1/tracks/5gKt31WKlTPG...
# 26120  https://api.spotify.com/v1/tracks/4VTgjtmey70U...
# 26121  https://api.spotify.com/v1/tracks/4D3qYj3LzPRU...
# 26122  https://api.spotify.com/v1/tracks/4jmpbm9CGmFX...
# 26123  https://api.spotify.com/v1/tracks/1YJHxl53keKu...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/4Sdu...       298457
# 1      https://api.spotify.com/v1/audio-analysis/3cr3...       344693
# 2      https://api.spotify.com/v1/audio-analysis/31fw...       269500
# 3      https://api.spotify.com/v1/audio-analysis/2QUE...       217373
# 4      https://api.spotify.com/v1/audio-analysis/5sA7...       160600
# ...                                                  ...          ...
# 26119  https://api.spotify.com/v1/audio-analysis/5gKt...       198587
# 26120  https://api.spotify.com/v1/audio-analysis/4VTg...       402200
# 26121  https://api.spotify.com/v1/audio-analysis/4D3q...       365267
# 26122  https://api.spotify.com/v1/audio-analysis/4jmp...       407092
# 26123  https://api.spotify.com/v1/audio-analysis/1YJH...       494960
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 26119               4
# 26120               4
# 26121               4
# 26122               4
# 26123               4
#
# [26124 rows x 20 columns]

# %%
print(df_spotify.duplicated().sum())
# Out:
# 393

# %%
df_spotify = df_spotify.drop_duplicates()
df_spotify.shape
# Out:
# (25731, 20)

# %%
df_spotify.isna().sum()
# Out:
# track_name          2
# artist_name         2
# uri                 0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
df_spotify = df_spotify.dropna()
df_spotify.shape
# Out:
# (25729, 20)

# %%
df_spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26124 entries, 0 to 26123
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      26124 non-null  float64
#  1   energy            26124 non-null  float64
#  2   key               26124 non-null  int64
#  3   loudness          26124 non-null  float64
#  4   mode              26124 non-null  int64
#  5   speechiness       26124 non-null  float64
#  6   acousticness      26124 non-null  float64
#  7   instrumentalness  26124 non-null  float64
#  8   liveness          26124 non-null  float64
#  9   valence           26124 non-null  float64
#  10  tempo             26124 non-null  float64
#  11  duration_ms       26124 non-null  int64
#  12  time_signature    26124 non-null  int64
# dtypes: float64(9), int64(4)
# memory usage: 2.6 MB

# %%
df_spotify = df_spotify.drop(["track_name","artist_name","uri","type","id","track_href","analysis_url"], axis = 1)

# %%
df_spotify.shape
# Out:
# (26124, 13)

# %%
# K-means
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler

from matplotlib.lines import Line2D

# %%
X=df_spotify
from sklearn.preprocessing import StandardScaler

X_prep = StandardScaler().fit_transform(X)

# Now, all features will have the same weight.
pd.DataFrame(X_prep,columns=X.columns).head()
# Out:
#    danceability    energy       key  loudness     mode  speechiness  \
# 0     -0.540471 -0.902243 -1.479681 -0.958984  0.74188     1.245413
# 1     -1.449153 -1.709595 -1.200932 -0.660918  0.74188    -0.556215
# 2     -1.923751 -1.642315  0.471559 -1.811206  0.74188    -0.613178
# 3      0.200364 -1.065635  0.471559 -1.090832  0.74188    -0.378701
# 4     -1.182915  0.587513 -0.922184  0.922948  0.74188     0.450577
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0      1.176615         -0.428441 -0.793713 -0.822707  1.009611     0.642955
# 1      0.413145         -0.346252  0.249063 -1.138088 -0.429046     1.157622
# 2     -0.753225         -0.378297 -0.299435 -1.236645 -1.528878     0.320626
# 3      1.762446         -0.428499 -0.362480 -1.386451 -1.392143    -0.259616
# 4     -0.728280         -0.428501  1.314535 -0.933091  1.053498    -0.891573
#
#    time_signature
# 0        0.185288
# 1        0.185288
# 2        0.185288
# 3        0.185288
# 4        0.185288

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(X_prep)
# Out:
# KMeans(n_clusters=3, random_state=1234)

# %%
clusters = kmeans.predict(X_prep)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     5509
# 1    14291
# 2     6324
# dtype: int64

# %%
clusters
# Out:
# array([0, 0, 0, ..., 0, 2, 1], dtype=int32)

# %%
plt.figure(figsize=(5, 5))
plt.scatter(X_prep[:, 0], X_prep[:, 6], c=clusters,alpha=0.5)
plt.show()

# %%
X_prep[:,0]
# Out:
# array([-0.54047149, -1.44915291, -1.92375085, ...,  0.81386898,
#        -0.30317252,  0.57657001])

# %%
kmeans.inertia_
# Out:
# 273947.49878540006
